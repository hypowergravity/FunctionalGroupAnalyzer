# %%
from src.FunctionalCatalog import main

# %%
main("C1C=CC=C(/C(/C(=O)NCCCl)=C\\OC)C=1")
# Out:
# Found 25 matching functional groups:
#   - acyl group
#   - alkene
#   - alkyl group
#   - alkylbenzene
#   - alpha,beta-unsaturated ketone
#   - arene
#   - aromatic compound
#   - benzenes
#   - carbonyl group
#   - carboxamide
#   - chloroalkane
#   - cyclic compound
#   - enol ether
#   - ether
#   - halo group
#   - haloalkane
#   - halohydrocarbon
#   - hydrocarbyl group
#   - imino group
#   - ketone
#   - methoxy group
#   - methyl group
#   - organyl group
#   - phenyl group
#   - secondary amine
# === Individual Pattern Matches ===
# ['acyl group',
#  'alkene',
#  'alkyl group',
#  'alkylbenzene',
#  'alpha,beta-unsaturated ketone',
#  'arene',
#  'aromatic compound',
#  'benzenes',
#  'carbonyl group',
#  'carboxamide',
#  'chloroalkane',
#  'cyclic compound',
#  'enol ether',
#  'ether',
#  'halo group',
#  'haloalkane',
#  'halohydrocarbon',
#  'hydrocarbyl group',
#  'imino group',
#  'ketone',
#  'methoxy group',
#  'methyl group',
#  'organyl group',
# ...

# %%
main("EQ_0.mol")
# Out:
# Found 19 matching functional groups:
#   - alkene
#   - alkyl group
#   - alkylbenzene
#   - arene
#   - aromatic compound
#   - benzenes
#   - cyclic compound
#   - halo group
#   - haloalkane
#   - haloarene
#   - halohydrocarbon
#   - hydrocarbyl group
#   - iodoalkane
#   - methyl group
#   - organyl group
#   - phenyl group
#   - tertiary amine
#   - tertiary phosphine
#   - triphenylphosphine
# === Individual Pattern Matches ===
# ['alkene',
#  'alkyl group',
#  'alkylbenzene',
#  'arene',
#  'aromatic compound',
#  'benzenes',
#  'cyclic compound',
#  'halo group',
#  'haloalkane',
#  'haloarene',
#  'halohydrocarbon',
#  'hydrocarbyl group',
#  'iodoalkane',
#  'methyl group',
#  'organyl group',
#  'phenyl group',
#  'tertiary amine',
#  'tertiary phosphine',
#  'triphenylphosphine']
